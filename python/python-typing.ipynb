# %%
n1 = 1
f1 = 1.23  # 传给
s1 = "abc"
m1 = {"a", "d", "f"}  # map set
l1 = [1, 2, 3]
d1 = {"a": 1, "b": 2}
t1 = tuple([1, 2])

# 正常情况下 自带的类型 str int 等可以用做类型的表示
# 其中 int 属于float 不会导致报错


def g_n(arg: str) -> int:
    g_n(n1)
    g_n(f1)
    g_n(s1)
    g_n(m1)
    g_n(l1)
    g_n(d1)
    g_n(t1)
    return t1


def g_n2(arg: list):
    g_n2(m1)
    g_n2(l1)  # 正确
    g_n2(d1)
    g_n2(t1)
    return arg


x: int = f1


class A():
    pass


class B():
    pass


def g_cls(arg: A):
    return arg


g_cls(A())


# 怎么样检查复杂的类型
from typing import Union
from typing import List, Any,Tuple,Dict,Set
from typing import Optional
from typing import Sequence,Callable
from typing import TypeVar
T = TypeVar('T')

a: List[int] = [1, 2, 3]
b: List[float] = ["a", "b", 1, "e"]
c: List[Union[int, str]] = [1, 2, "a"]
d: List[Any] = [1, 2, 3]
d3: Any = 1
e: List[List[int]] = [[1,2],[3,4]]
f: Dict[str,str] ={"a":"b"}
g: Set[str] ={"a","b","c"}
h: Set[bool]  = {True,False}
i: Tuple[int,int,int]  =(1,2,3)


def foo(output: Optional[bool]=False):
    pass

# anything can be index ,also include string. set is not sequence.
def foo2(seq:Sequence[str]):
    pass


def foo3(func:Callable[[int,int],int]):
    pass


def get_item(lst:List[T],idx:int)->T:
    return lst[idx]
